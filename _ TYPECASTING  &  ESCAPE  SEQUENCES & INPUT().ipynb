# %% [markdown]
# # type casting
#
# type casting is a  method  to convert one  data  type to another  data type .
# - int()
# - float()
# - bool()
# - complex()
# - str()
# - list()
# - tuple()
# - dict()
# - set()

# %%
int('90')
# Out:
# 90

# %%
x='98'
print(int(x))
# Out:
# 98

# %%
type(x)
# Out:
# str

# %%
# convert  a float to boolean
bool(232.22)
# Out:
# True

# %%
243.28
print(bool)
# Out:
# <class 'bool'>

# %%
bool(243.28)
# Out:
# True

# %%
bool(00000)
# Out:
# False

# %%
# convert boolean to complex
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
 # convert string to boolean 
bool("my name is akhilesh")
# Out:
# True

# %%
bool('94')
# Out:
# True

# %%
# convert integer to float
float(45)
# Out:
# 45.0

# %%
var="45"
print(type(int(var))) # this is creating a new integer  but  not  changing  the  vaeiable var
# Out:
# <class 'int'>

# %% [markdown]
# # Escape Sequences

# %%
 print("python  has many "date types"")
# Out:
#   Cell In[2], line 1
#     print("python  has many "date types"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(', python has  many "data types"')
# Out:
# , python has  many "data types"

# %%
print("python has many \"data types\"")
# Out:
# python has many "data types"

# %%
    print("python has many \'data types\'")
# Out:
# python has many 'data types'

# %% [markdown]
# # Escape Sequences
#
#      code                            result
#
#       \'                              single quote
#
#       \\                              backslash
#
#       \n                               new line
#
#       \b                               backspace
#
#       \t                               tab
#
#       \r                               carriage return

# %%
x='89'
type(x)
# Out:
# str

# %%
int(type(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 int(type(x))
#
# NameError: name 'x' is not defined

# %%
type(int(x))
# Out:
# int

# %%
print("python  has many\"data types\"")
# Out:
# python  has many"data types"

# %%
print("data\ \student")
# Out:
# data\ \student

# %%
print("data\student")
# Out:
# data\student

# %%
print("python has many \\"data types\"")
# Out:
#   Cell In[19], line 1
#     print("python has many \\"data types\"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("python has many \ \"data types\"")
# Out:
# python has many \ "data types"

# %%
print("python is easy\n data student")
# Out:
# python is easy
#  data student

# %%
print("python is good \n python is many")
# Out:
# python is good
#  python is many

# %%
print("python is good\b python\b is many")
# Out:
#  is many

# %%
print("python\b")
# Out:
# python

# %%
print("python\b\b")
# Out:
# python

# %%
print("python\b\b\b")
# Out:
# python

# %%
print("python\b\b\b\b")
# Out:
# python

# %%
print("python\b\b\b\b\b")
# Out:
# python

# %%
print("python\b\b\b\b\b\b\b\b\b\b")
# Out:
# python

# %%
print("pyth\bo\bn\b")
# Out:
# n

# %%
print("pyth\bo\bn")
# Out:
# n

# %%
print("bhatt\b\b")
# Out:
# bhatt

# %%
print("bhatt\a")
# Out:
# bhatt

# %%
print("pyth\bo")
# Out:
# o

# %%
print("data\bs\bn\b")
# Out:
# n

# %%
print("python \t date science")
# Out:
# python 	 date science

# %%
print("python \t date \t science")
# Out:
# python 	 date 	 science

# %%
print("hello\ta")
# Out:
# hello	a

# %%
print("python\rdata")
# Out:
# data

# %%
print("akhilesh\rbhatt")
# Out:
# bhatt

# %%
print("python\rdata\rhe")
# Out:
# he

# %% [markdown]
# # taking input from users
#
# input()
# - just like print() is used to give some output() is used to take some input from the user

# %%
x = input()
# Out:
# hello world

# %%
x=input()
# Out:
#  45

# %%
x =input()
# Out:
# helllll

# %%
x
# Out:
# 'hello world'

# %%
x = input()
y =input()

# %%
x = input()

# %%
y = int(input('Enter a nambar'))
# Out:
# Enter a nambar56

# %%
print(y)
print(type(y))
# Out:
# 56
# <class 'int'>

# %%
#let us check the data type of x
type(x)
# Out:
# str

# %%
y = int(input('enter a nambar'))
# Out:
# enter a nambar56

# %%
print(y)
print(type(y))
# Out:
# 56
# <class 'int'>

# %%
#program to  calculate the sum of two numbar
print('entar two numbar to add')
num1 = int(input())
num2 = int(input())
sum = num1+num2
print('the sum of',num1,'and',num2,'is',sum)
# Out:
# entar two numbar to add
#  5
#  5
# the sum of 5 and 5 is 10

# %%
print('two numbers')
x = int(input())
y = int(input())
sum = x+y
print( sum)
# Out:
# two numbers
# 23
# 56
# 79

# %%
print('two numbers')
x = int(input())
y = int(input())
sum = x%y
print(x 'and'y'is',sum)

# %%
print('singup for Gmail account')
name =input('firstname:') 
name = input('lastname:')
username = input('username:')
Dob = input('Dob:')
passrord = input('psssrord:')
# Out:
# singup for Gmail account
# firstname: Akhilesh
# lastname: Bhatt
# username: Akhilesh Bhatt
# Dob: 45685
# psssrord: 58526951

# %%
print('singup for Gmail account')
name =input('firstname') 
name = input('lastname')
username = input('username')
Dob = input('Dob')
passrord = input('psssrord')
# Out:
# singup for Gmail account

# %%
# Out:
# name. name

# %%
print(name)
# Out:
# bhatt

# %%
print(name)
print(Gmailid)
print(passrord)
# Out:
#   Cell In[5], line 1
#     print input(name)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(Dob)
# Out:
# 26/01/2004

# %%
print(username)
# Out:
# akhilesh bhatt

# %%
print(passrord)
# Out:
# 8192073749

# %%
print('singup for Gmail account')
name =input('firstname') 
name = input('lastname')
username = input('username')
Dob = input('Dob')
passrord = input('passrord')
# Out:
# singup for Gmail account
# firstnameAkhilesh
# lastnamebhatt
# usernameAkhilesh bhatt
# Dob26/01/2004
# passrord263623

# %%
print(name)
# Out:
# bhatt

# %%
print(Dob)
# Out:
# 26/01/2004

# %%
print(passrord)
# Out:
# 263623

# %%
print(Dob)
# Out:
# 26/01/2004

# %%
print(name + Dob+ passrord +username)
# Out:
# bhatt26/01/2004263623Akhilesh bhatt

# %%
print('name','Dob')
# Out:
# name Dob

# %%
print('singup for Gmail account')
name =input('firstname:') 
name = input('lastname:')
username = input('username:')
Dob = input('Dob:')
passrord = input('passrord:')
# Out:
# singup for Gmail account
# firstname:Akhilesh
# lastname:bhatt
# username:Akhilesh bhatt
# Dob:26/01/2004
# passrord:263623

# %% [markdown]
# # exerciset
# problem 1> builld  program to get the following  output  using print() and escap  sequence:

# %%
print('\tphysics\t   |\tCHEMIST   |\tBIOLGY' )

print("JOHK\t 28 \t\t 20\t   \t 24 \n")
print("jack\t 21 \t\t 18\t   \t 21\n" )
print("DICK\t 23 \t\t 30\t    \t 23\n" )
# Out:
# 	physics	   |	CHEMIST   |	BIOLGY
# JOHK	 28 		 20	   	 24
#
# jack	 21 		 18	   	 21
#
# DICK	 23 		 30	    	 23

# %%
print('\tphysics|\tchemistry\t|\tBiology')
print('John\t\28\t\t\20\t\t\24')
print('jack\t\21\t\t\18\t\t\21')
print('Dick\t\23\t\t\30\t\t\23')
# Out:
# 	physics|	chemistry	|	Biology
# John	8
# jack			8
# Dick

# %%
print('\tPHYSICS\t   |\tCHEMISTRY\t |\tBIOLOGY\n')
print('John\t  28\t\t  24\t\t    \t   20\n')
print('jack\t  25\t\t  21\t\t     \t   18\n')
print('Dick\t  19\t\t  23\t\t      \t   30\n')
# Out:
# 	PHYSICS	   |	CHEMISTRY	 |	BIOLOGY
#
# John	  28		  24		    	   20
#
# jack	  25		  21		     	   18
#
# Dick	  19		  23		      	   30

# %%
x=18
y=('python')
print(x)
print(y)
# Out:
# 18
# python

# %%
x
# Out:
# 18

# %%
y
# Out:
# 'python'

# %%
x
# Out:
# 18

# %%
y
# Out:
# 'python'

# %%
x=12
y('hello')
print(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 x=12
# ----> 2 y('hello')
#       3 print(x)
#       4 print(y)
#
# TypeError: 'str' object is not callable

# %%
x
# Out:
# 12

# %%
y
# Out:
# 'hello'

# %%
x,y=y,x
print(x)

# %%
print(y)
# Out:
# 18

# %%
x
# Out:
# 18

# %%
x,y=y,x
print(x)
print(y)
# Out:
# 18
# python

# %%
x
# Out:
# 18

# %%
y
# Out:
# 'python'

# %%
print('\tHIND    |\tEnglish\t |\t Data')
print('Rohit\t 99\t  \t 90\t \t  88\n')
print('kamal\t 70\t  \t 80\t \t  50\n')
print('Avi\t 100\t   \t 95\t \t  65\n')
# Out:
# 	HIND    |	English	 |	 Data
# Rohit	 99	  	 90	 	  88
#
# kamal	 70	  	 80	 	  50
#
# Avi	 100	   	 95	 	  65

# %%
print('two numbar')
x = int(input())
y = int(input())
sum = x,y
print(x,y,x*y)
# Out:
# two numbar
# 56
# 23
# 56 23 1288

# %%
print('two numbar')
x = int(input())
y = int(input())
print(x,+ y,)
# Out:
# two numbar
# 23
# 56
# 23 56

# %%
print('two numbar')
x = int(input())
y = int(input())
sum = xy
print(x,'+',y,)
# Out:
# two numbar
# 23
# 56
# 23 + 56 True

# %%
print('two numbar')
x = input()
y = input()
print(x,"+",y,'=',x+y)
# Out:
# two numbar
# 23
# 56
# 23 + 56 = 2356

# %%
x,y=y,x
print(x)
# Out:
# 56

# %%
x =int(input())
y = int(input())
print(5*3,6*2,'=',12+15)
# Out:
# 23
# 56
# 15 12 = 27

# %%
x =int(input())
y = int(input())
print(5*3,6*2,'=',12+15)
# Out:
# 23
# 56
# 15 12 = 27

# %%
x =int(input())
y = int(input())
print(5*3,6*2,12+15)
# Out:
# 23
# 56
# 15 12 27

# %%
x =int(input())
y = int(input())
print(x*x,y*y)
# Out:
# 23
# 56
# 529 3136

# %%
input()
print(28)
# Out:
# 28
# 28

# %%
x=2

# %%
float(x)
# Out:
# 2.0

# %%
str(x)
# Out:
# '2'

# %%
bool(x)
# Out:
# True

# %%
tuple(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tuple(x)
#
# TypeError: 'int' object is not iterable

# %%
dict(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dict(x)
#
# TypeError: 'int' object is not iterable

# %%
set(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 set(x)
#
# TypeError: 'int' object is not iterable

# %%
list(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 list(x)
#
# TypeError: 'int' object is not iterable

# %%
complex(x)
# Out:
# (2+0j)

# %%
range(2)
# Out:
# range(0, 2)

# %%
y = 2.01

# %%
int(y)
# Out:
# 2

# %%
str(y)
# Out:
# '2.01'

# %%
tuple(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tuple(y)
#
# TypeError: 'float' object is not iterable

# %%
set(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 set(y)
#
# TypeError: 'float' object is not iterable

# %%
list(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 list(y)
#
# TypeError: 'float' object is not iterable

# %%
dict(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dict(y)
#
# TypeError: 'float' object is not iterable

# %%
complex(y)
# Out:
# (2.01+0j)

# %%
bool(y)
# Out:
# True

# %%
c='hello'

# %%
int(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int(c)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
str(c)
# Out:
# 'hello'

# %%
bool(c)
# Out:
# True

# %%
float(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 float(c)
#
# ValueError: could not convert string to float: 'hello'

# %%
tuple(c)
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
list(c)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
set(c)
# Out:
# {'e', 'h', 'l', 'o'}

# %%
complex(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex(c)
#
# ValueError: complex() arg is a malformed string

# %%
a=True

# %%
int(a)
# Out:
# 1

# %%
float(a)
# Out:
# 1.0

# %%
str(a)
# Out:
# 'True'

# %%
tuple(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 tuple(a)
#
# TypeError: 'bool' object is not iterable

# %%
dict(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 dict(a)
#
# TypeError: 'bool' object is not iterable

# %%
list(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 list(a)
#
# TypeError: 'bool' object is not iterable

# %%
set(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 set(a)
#
# TypeError: 'bool' object is not iterable

# %%
complex(a)
# Out:
# (1+0j)

# %%
None(a)
# Out:
# <>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# C:\Users\ARJUN  BHATT\AppData\Local\Temp\ipykernel_1768\1362416499.py:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
#   None(a)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 None(a)
#
# TypeError: 'NoneType' object is not callable

# %%
h=1,2

# %%
int(h)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 int(h)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'tuple'

# %%
float(h)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 float(h)
#
# TypeError: float() argument must be a string or a real number, not 'tuple'

# %%
str(h)
# Out:
# '(1, 2)'

# %%
bool(h)
# Out:
# True

# %%
dict(h)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 dict(h)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
set(h)
# Out:
# {1, 2}

# %%
list(h)
# Out:
# [1, 2]

# %%
complex(h)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 complex(h)
#
# TypeError: complex() first argument must be a string or a number, not 'tuple'

# %%
g={1}

# %%
int(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 int(g)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'set'

# %%
float(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 float(g)
#
# TypeError: float() argument must be a string or a real number, not 'set'

# %%
str(g)
# Out:
# '{1}'

# %%
bool(g)
# Out:
# True

# %%
tuple(g)
# Out:
# (1,)

# %%
set(g)
# Out:
# {1}

# %%
list(g)
# Out:
# [1]

# %%
complex(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 complex(g)
#
# TypeError: complex() first argument must be a string or a number, not 'set'

# %%
v=set('hello')

# %%
int(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 int(v)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'set'

# %%
float(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 float(v)
#
# TypeError: float() argument must be a string or a real number, not 'set'

# %%
str(v)
# Out:
# "{'l', 'e', 'o', 'h'}"

# %%
bool(v)
# Out:
# True

# %%
complex(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 complex(v)
#
# TypeError: complex() first argument must be a string or a number, not 'set'

# %%
dict(v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 dict(v)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
list(v)
# Out:
# ['l', 'e', 'o', 'h']

# %%
tuple(v)
# Out:
# ('l', 'e', 'o', 'h')

# %%
b=[1,2,3]

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 int(b)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
float(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 float(b)
#
# TypeError: float() argument must be a string or a real number, not 'list'

# %%
set(b)
# Out:
# {1, 2, 3}

# %%
dict(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 dict(b)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
complex(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 complex(b)
#
# TypeError: complex() first argument must be a string or a number, not 'list'

# %%
bool(b)
# Out:
# True

# %%
tuple(b)
# Out:
# (1, 2, 3)
